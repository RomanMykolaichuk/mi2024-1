# %%
with open("./data/4.txt","r") as f:
    content = f.read()

content
# Out:
# '"name": "John Doe",\n"age": 50,\n"city": "New York" '

# %%
import json

text = content 

data = json.loads("{" + text + "}")

print(data)
print(type(data))
# Out:
# {'name': 'John Doe', 'age': 30, 'city': 'New York'}
# <class 'dict'>

# %%
with open("./data/4a.txt", "w", encoding="utf-8") as f:
    f.write(str(data))

# %%
import pandas as pd

# %%
df = pd.read_csv("./data/directions_20_rows.csv", encoding="utf-8")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       20 non-null     object
#  1   direction  20 non-null     object
#  2   amount     20 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 612.0+ bytes

# %%
df.head(20)
# Out:
#           date direction  amount
# 0   2026-08-01     North      12
# 1   2026-08-02      East       7
# 2   2026-08-03     South      15
# 3   2026-08-04      West       9
# 4   2026-08-05     North      18
# 5   2026-08-06      East      11
# 6   2026-08-07     South       6
# 7   2026-08-08      West      14
# 8   2026-08-09     North      10
# 9   2026-08-10      East      20
# 10  2026-08-11     South       8
# 11  2026-08-12      West      13
# 12  2026-08-13     North      16
# 13  2026-08-14      East       5
# 14  2026-08-15     South      19
# 15  2026-08-16      West       7
# 16  2026-08-17     North      11
# 17  2026-08-18      East      17
# 18  2026-08-19     South       9
# 19  2026-08-20      West      12

# %%
east_df = df[df['direction'] == 'East']

east_df.head()
# Out:
#           date direction  amount
# 1   2026-08-02      East       7
# 5   2026-08-06      East      11
# 9   2026-08-10      East      20
# 13  2026-08-14      East       5
# 17  2026-08-18      East      17

# %%
content = "Some content\n"

with open("some.txt","w") as f:
    f.write(content)

# %%
with open("some.txt","a") as f:
    f.write(content)

# %%
import pandas as pd

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from datetime import datetime

# %%
def read_with_log(data_frame):
    data_frame = pd.read_csv("./data/data.csv")
    output1 = f"{datetime.now()} - read into data_frame"
    with open("./data/log.txt", "a") as f:
        f.write(output1 + "\n")
    return output1

# %%
df = pd.DataFrame()
read_with_log(df)
# Out:
# '2026-08-14 10:36:27.622907 - read into data_frame'
